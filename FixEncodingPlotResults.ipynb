# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
from dataset_4channel import BeetleDataset
import functions_rotation as fr

# %%
raw_files = ['raw_densebox_1', 'raw_densebox_2', 'raw_densebox_3', 'raw_densebox_4', 'raw_densebox_5']
label_files = ['class_lab_densebox_1', 'class_lab_densebox_2', 'class_lab_densebox_3', 'class_lab_densebox_4', 'class_lab_densebox_5']

db = BeetleDataset(raw_files, label_files)

# %%
norm_factor = 25
x, y, x_thresh = db.generate_batch(n=10)
x_down, y_down, x_thresh_down = fr.downsample(x, y, x_thresh)

a,b = fr.encode_y(x_down, norm_factor, y_down, x_thresh_down)
# Out:
# /usr/local/lib/python2.7/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
import matplotlib.pyplot as plt
# So the encoding is blank, that's pretty interesting
for i in range(a.shape[0]):
    plt.imshow(a[i,0].data)
    plt.show()

# %%
# Let's plot all the encoded channels and verify that everyhing works
# DOes the loss converge at all, if not that imples some logical bug
# Otherwise try a tiny beetle datase where you fix the no of beetles
# id debug, solve using seqeuntial probability shift
# graph combinatorial complexity decomposition
# copy paste code locally and remove whatev3er does not work
# geometric heterogenity is still a bug which has not been fixed and needs to be fixed

# %%
for i in range(b.shape[0]):
    for c in range(b.shape[1]):
        plt.figure(figsize=(10,10))
        plt.imshow(b[0,2,:,:].data)
        plt.colorbar()
        plt.show()

# %%
import matplotlib.pyplot as plt
for i in range(b.shape[0]):
    plt.figure()
    plt.yscale('log', nonposy='clip')
    plt.hist(b[i,:,:,:].data.ravel(), bins=20)
    print(b[i,:,:,:].data.max(), b[i,:,:,:].data.min())
    plt.show()
# Out:
# (0.88, -0.85000002)
# (0.28, -0.25)
# (0.73000002, -0.70999998)
# (0.80000001, -0.76999998)
# (1.0, -0.98000002)
# (0.18000001, -0.13)
# (0.72000003, -0.70999998)
# (0.89999998, -0.87)
# (0.75, -0.77999997)
# (0.56, -0.52999997)

# %%
b.data.ravel().max()
# Out:
# 1.0
